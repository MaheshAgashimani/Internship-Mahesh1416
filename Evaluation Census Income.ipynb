# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/census_income.csv')
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3       Married-civ-spouse      Prof-specialty            Wife   Black
# 4       Married-civ-spouse     Exec-managerial            Wife   White
# ...                    ...                 ...             ...     ...
# 32555   Married-civ-spouse        Tech-support            Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32557              Widowed        Adm-clerical       Unmarried   White
# 32558        Never-married        Adm-clerical       Own-child   White
# 32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#            Sex  Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# 0         Male             0             0              13   United-States
# 1         Male             0             0              40   United-States
# 2         Male             0             0              40   United-States
# 3       Female             0             0              40            Cuba
# 4       Female             0             0              40   United-States
# ...        ...           ...           ...             ...             ...
# 32555   Female             0             0              38   United-States
# 32556     Male             0             0              40   United-States
# 32557   Female             0             0              40   United-States
# 32558     Male             0             0              20   United-States
# 32559   Female         15024             0              40   United-States
#
#        Income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32555   <=50K
# 32556    >50K
# 32557   <=50K
# 32558   <=50K
# 32559    >50K
#
# [32560 rows x 15 columns]

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/census_income.csv')

# %%
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3       Married-civ-spouse      Prof-specialty            Wife   Black
# 4       Married-civ-spouse     Exec-managerial            Wife   White
# ...                    ...                 ...             ...     ...
# 32555   Married-civ-spouse        Tech-support            Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32557              Widowed        Adm-clerical       Unmarried   White
# 32558        Never-married        Adm-clerical       Own-child   White
# 32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#            Sex  Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# 0         Male             0             0              13   United-States
# 1         Male             0             0              40   United-States
# 2         Male             0             0              40   United-States
# 3       Female             0             0              40            Cuba
# 4       Female             0             0              40   United-States
# ...        ...           ...           ...             ...             ...
# 32555   Female             0             0              38   United-States
# 32556     Male             0             0              40   United-States
# 32557   Female             0             0              40   United-States
# 32558     Male             0             0              20   United-States
# 32559   Female         15024             0              40   United-States
#
#        Income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32555   <=50K
# 32556    >50K
# 32557   <=50K
# 32558   <=50K
# 32559    >50K
#
# [32560 rows x 15 columns]

# %%
df.head(2)
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
#
#         Marital_status          Occupation    Relationship    Race    Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White   Male
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K

# %%
df.tail(2)
# Out:
#        Age      Workclass  Fnlwgt Education  Education_num  \
# 32558   22        Private  201490   HS-grad              9
# 32559   52   Self-emp-inc  287927   HS-grad              9
#
#             Marital_status        Occupation Relationship    Race      Sex  \
# 32558        Never-married      Adm-clerical    Own-child   White     Male
# 32559   Married-civ-spouse   Exec-managerial         Wife   White   Female
#
#        Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 32558             0             0              20   United-States   <=50K
# 32559         15024             0              40   United-States    >50K

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
df['Native_country'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
df['Occupation'].unique()
# Out:
# array([' Exec-managerial', ' Handlers-cleaners', ' Prof-specialty',
#        ' Other-service', ' Adm-clerical', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
df.loc[df.Native_country==' ?']
# Out:
#        Age          Workclass  Fnlwgt      Education  Education_num  \
# 13      40            Private  121772      Assoc-voc             11
# 37      31            Private   84154   Some-college             10
# 50      18            Private  226956        HS-grad              9
# 60      32                  ?  293936        7th-8th              4
# 92      30            Private  117747        HS-grad              9
# ...    ...                ...     ...            ...            ...
# 32448   44       Self-emp-inc   71556        Masters             14
# 32468   58       Self-emp-inc  181974      Doctorate             16
# 32491   42   Self-emp-not-inc  217597        HS-grad              9
# 32509   39            Private  107302        HS-grad              9
# 32524   81                  ?  120478      Assoc-voc             11
#
#                Marital_status       Occupation    Relationship  \
# 13         Married-civ-spouse     Craft-repair         Husband
# 37         Married-civ-spouse            Sales         Husband
# 50              Never-married    Other-service       Own-child
# 60      Married-spouse-absent                ?   Not-in-family
# 92         Married-civ-spouse            Sales            Wife
# ...                       ...              ...             ...
# 32448      Married-civ-spouse            Sales         Husband
# 32468           Never-married   Prof-specialty   Not-in-family
# 32491                Divorced            Sales       Own-child
# 32509      Married-civ-spouse   Prof-specialty         Husband
# 32524                Divorced                ?       Unmarried
#
#                       Race      Sex  Capital_gain  Capital_loss  \
# 13      Asian-Pac-Islander     Male             0             0
# 37                   White     Male             0             0
# 50                   White   Female             0             0
# 60                   White     Male             0             0
# 92      Asian-Pac-Islander   Female             0          1573
# ...                    ...      ...           ...           ...
# 32448                White     Male             0             0
# 32468                White   Female             0             0
# 32491                White     Male             0             0
# 32509                White     Male             0             0
# 32524                White   Female             0             0
#
#        Hours_per_week Native_country  Income
# 13                 40              ?    >50K
# 37                 38              ?    >50K
# 50                 30              ?   <=50K
# 60                 40              ?   <=50K
# 92                 35              ?   <=50K
# ...               ...            ...     ...
# 32448              50              ?    >50K
# 32468              99              ?   <=50K
# 32491              50              ?   <=50K
# 32509              45              ?    >50K
# 32524               1              ?   <=50K
#
# [583 rows x 15 columns]

# %%
df.loc[df.Occupation==' ?']
# Out:
#        Age Workclass  Fnlwgt      Education  Education_num  \
# 26      54         ?  180211   Some-college             10
# 60      32         ?  293936        7th-8th              4
# 68      25         ?  200681   Some-college             10
# 76      67         ?  212759           10th              6
# 105     17         ?  304873           10th              6
# ...    ...       ...     ...            ...            ...
# 32529   35         ?  320084      Bachelors             13
# 32530   30         ?   33811      Bachelors             13
# 32538   71         ?  287372      Doctorate             16
# 32540   41         ?  202822        HS-grad              9
# 32541   72         ?  129912        HS-grad              9
#
#                Marital_status Occupation    Relationship                 Race  \
# 26         Married-civ-spouse          ?         Husband   Asian-Pac-Islander
# 60      Married-spouse-absent          ?   Not-in-family                White
# 68              Never-married          ?       Own-child                White
# 76         Married-civ-spouse          ?         Husband                White
# 105             Never-married          ?       Own-child                White
# ...                       ...        ...             ...                  ...
# 32529      Married-civ-spouse          ?            Wife                White
# 32530           Never-married          ?   Not-in-family   Asian-Pac-Islander
# 32538      Married-civ-spouse          ?         Husband                White
# 32540               Separated          ?   Not-in-family                Black
# 32541      Married-civ-spouse          ?         Husband                White
#
#            Sex  Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# 26        Male             0             0              60           South
# 60        Male             0             0              40               ?
# 68        Male             0             0              40   United-States
# 76        Male             0             0               2   United-States
# 105     Female         34095             0              32   United-States
# ...        ...           ...           ...             ...             ...
# 32529   Female             0             0              55   United-States
# 32530   Female             0             0              99   United-States
# 32538     Male             0             0              10   United-States
# 32540   Female             0             0              32   United-States
# 32541     Male             0             0              25   United-States
#
#        Income
# 26       >50K
# 60      <=50K
# 68      <=50K
# 76      <=50K
# 105     <=50K
# ...       ...
# 32529    >50K
# 32530   <=50K
# 32538    >50K
# 32540   <=50K
# 32541   <=50K
#
# [1843 rows x 15 columns]

# %%
#As above data observed  "Native Country" missing 583 values & Ocuupation missing 1816 values.
# So dropping null values from both the column

# %%
df.drop(df[df['Native_country'] == ' ?'].index,inplace = True)

# %%
df.drop(df[df['Occupation'] == ' ?'].index,inplace = True)

# %%
df['Native_country'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
df['Occupation'].unique()
# Out:
# array([' Exec-managerial', ' Handlers-cleaners', ' Prof-specialty',
#        ' Other-service', ' Adm-clerical', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %%
#EDA Part Using countplot for categorical data
import seaborn as sns

# %%
ax=sns.countplot(x="Workclass",data=df)
print(df["Workclass"].value_counts())
# Out:
#  Private             22286
#  Self-emp-not-inc     2499
#  Local-gov            2067
#  State-gov            1278
#  Self-emp-inc         1074
#  Federal-gov           943
#  Without-pay            14
# Name: Workclass, dtype: int64

# %%
ax=sns.countplot(x="Education",data=df)
print(df["Education"].value_counts())
# Out:
#  HS-grad         9840
#  Some-college    6678
#  Bachelors       5043
#  Masters         1627
#  Assoc-voc       1307
#  11th            1048
#  Assoc-acdm      1008
#  10th             820
#  7th-8th          557
#  Prof-school      542
#  9th              455
#  12th             377
#  Doctorate        375
#  5th-6th          288
#  1st-4th          151
#  Preschool         45
# Name: Education, dtype: int64

# %%
ax=sns.countplot(x="Marital_status",data=df)
print(df["Marital_status"].value_counts())
# Out:
#  Married-civ-spouse       14065
#  Never-married             9725
#  Divorced                  4214
#  Separated                  939
#  Widowed                    827
#  Married-spouse-absent      370
#  Married-AF-spouse           21
# Name: Marital_status, dtype: int64

# %%
ax=sns.countplot(x="Occupation",data=df)
print(df["Occupation"].value_counts())
# Out:
#  Prof-specialty       4038
#  Craft-repair         4030
#  Exec-managerial      3992
#  Adm-clerical         3720
#  Sales                3584
#  Other-service        3212
#  Machine-op-inspct    1966
#  Transport-moving     1572
#  Handlers-cleaners    1350
#  Farming-fishing       989
#  Tech-support          912
#  Protective-serv       644
#  Priv-house-serv       143
#  Armed-Forces            9
# Name: Occupation, dtype: int64

# %%
ax=sns.countplot(x="Relationship",data=df)
print(df["Relationship"].value_counts())
# Out:
#  Husband           12463
#  Not-in-family      7725
#  Own-child          4466
#  Unmarried          3212
#  Wife               1406
#  Other-relative      889
# Name: Relationship, dtype: int64

# %%
ax=sns.countplot(x="Race",data=df)
print(df["Race"].value_counts())
# Out:
#  White                 25932
#  Black                  2817
#  Asian-Pac-Islander      895
#  Amer-Indian-Eskimo      286
#  Other                   231
# Name: Race, dtype: int64

# %%
ax=sns.countplot(x="Sex",data=df)
print(df["Sex"].value_counts())
# Out:
#  Male      20379
#  Female     9782
# Name: Sex, dtype: int64

# %%
ax=sns.countplot(x="Native_country",data=df)
print(df["Native_country"].value_counts())
# Out:
#  United-States                 27503
#  Mexico                          610
#  Philippines                     188
#  Germany                         128
#  Puerto-Rico                     109
#  Canada                          107
#  India                           100
#  El-Salvador                     100
#  Cuba                             92
#  England                          86
#  Jamaica                          80
#  South                            71
#  China                            68
#  Italy                            68
#  Dominican-Republic               67
#  Vietnam                          64
#  Guatemala                        63
#  Japan                            59
#  Poland                           56
#  Columbia                         56
#  Iran                             42
#  Taiwan                           42
#  Haiti                            42
#  Portugal                         34
#  Nicaragua                        33
#  Peru                             30
#  Greece                           29
#  France                           27
#  Ecuador                          27
#  Ireland                          24
#  Hong                             19
#  Cambodia                         18
#  Trinadad&Tobago                  18
#  Thailand                         17
#  Laos                             17
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Hungary                          13
#  Honduras                         12
#  Scotland                         11
#  Holand-Netherlands                1
# Name: Native_country, dtype: int64

# %%
ax=sns.countplot(x="Income",data=df)
print(df["Income"].value_counts())
# Out:
#  <=50K    22653
#  >50K      7508
# Name: Income, dtype: int64

# %%
#visualization of target variable data is imbalanced

# %%
#Encoding of data

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Workclass']=le.fit_transform(df['Workclass'])
df['Education']=le.fit_transform(df['Education'])
df['Marital_status']=le.fit_transform(df['Marital_status'])
df['Occupation']=le.fit_transform(df['Occupation'])
df['Relationship']=le.fit_transform(df['Relationship'])
df['Race']=le.fit_transform(df['Race'])
df['Sex']=le.fit_transform(df['Sex'])
df['Native_country']=le.fit_transform(df['Native_country'])
df['Income']=le.fit_transform(df['Income'])

# %%
df
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          6   83311          9             13               2
# 1       38          4  215646         11              9               0
# 2       53          4  234721          1              7               2
# 3       28          4  338409          9             13               2
# 4       37          4  284582         12             14               2
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          4  257302          7             12               2
# 32556   40          4  154374         11              9               2
# 32557   58          4  151910         11              9               6
# 32558   22          4  201490         11              9               4
# 32559   52          5  287927         11              9               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0               4             0     4    1             0             0
# 1               6             1     4    1             0             0
# 2               6             0     2    1             0             0
# 3              10             5     2    0             0             0
# 4               4             5     4    0             0             0
# ...           ...           ...   ...  ...           ...           ...
# 32555          13             5     4    0             0             0
# 32556           7             0     4    1             0             0
# 32557           1             4     4    0             0             0
# 32558           1             3     4    1             0             0
# 32559           4             5     4    0         15024             0
#
#        Hours_per_week  Native_country  Income
# 0                  13              39       0
# 1                  40              39       0
# 2                  40              39       0
# 3                  40               5       0
# 4                  40              39       0
# ...               ...             ...     ...
# 32555              38              39       0
# 32556              40              39       1
# 32557              40              39       0
# 32558              20              39       0
# 32559              40              39       1
#
# [32560 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Age               int64
# Workclass         int32
# Fnlwgt            int64
# Education         int32
# Education_num     int64
# Marital_status    int32
# Occupation        int32
# Relationship      int32
# Race              int32
# Sex               int32
# Capital_gain      int64
# Capital_loss      int64
# Hours_per_week    int64
# Native_country    int32
# Income            int32
# dtype: object

# %%
#Using Bar Plot
sns.barplot(x='Occupation',y='Capital_gain',data=df,hue='Income')
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='Capital_gain'>

# %%
sns.barplot(x='Education',y='Hours_per_week',data=df,hue='Income')
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Hours_per_week'>

# %%
sns.scatterplot(x='Age',y='Income',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Income'>

# %%
sns.scatterplot(x='Fnlwgt',y='Income',data=df)
# Out:
# <AxesSubplot:xlabel='Fnlwgt', ylabel='Income'>

# %%
sns.scatterplot(x='Education_num',y='Income',data=df)
# Out:
# <AxesSubplot:xlabel='Education_num', ylabel='Income'>

# %%
sns.scatterplot(x='Capital_gain',y='Income',data=df)
# Out:
# <AxesSubplot:xlabel='Capital_gain', ylabel='Income'>

# %%
sns.scatterplot(x='Capital_loss',y='Income',data=df)
# Out:
# <AxesSubplot:xlabel='Capital_loss', ylabel='Income'>

# %%
sns.scatterplot(x='Hours_per_week',y='Income',data=df)
# Out:
# <AxesSubplot:xlabel='Hours_per_week', ylabel='Income'>

# %%
import matplotlib.pyplot as plt
sns.pairplot(df)
plt.savefig('pairplot.png')
plt.show()

# %%
#Correlation

# %%
df.corr()
# Out:
#                      Age  Workclass    Fnlwgt  Education  Education_num  \
# Age             1.000000   0.080548 -0.076511  -0.001111       0.043525
# Workclass       0.080548   1.000000 -0.032395   0.017892       0.037729
# Fnlwgt         -0.076511  -0.032395  1.000000  -0.027115      -0.044954
# Education      -0.001111   0.017892 -0.027115   1.000000       0.345431
# Education_num   0.043525   0.037729 -0.044954   0.345431       1.000000
# Marital_status -0.276378  -0.034338  0.032197  -0.040654      -0.063457
# Occupation     -0.005680   0.015719  0.000152  -0.038231       0.087778
# Relationship   -0.246456  -0.067401  0.009289  -0.012720      -0.091928
# Race            0.023373   0.044700 -0.023882   0.011158       0.032791
# Sex             0.081992   0.074917  0.025387  -0.027880       0.006131
# Capital_gain    0.080154   0.035340  0.000427   0.030577       0.124413
# Capital_loss    0.060166   0.007226 -0.009757   0.015025       0.079656
# Hours_per_week  0.101599   0.050738 -0.022889   0.059887       0.152528
# Native_country -0.001905   0.007644 -0.066709   0.078794       0.091547
# Income          0.242000   0.018103 -0.008978   0.078981       0.335317
#
#                 Marital_status  Occupation  Relationship      Race       Sex  \
# Age                  -0.276378   -0.005680     -0.246456  0.023373  0.081992
# Workclass            -0.034338    0.015719     -0.067401  0.044700  0.074917
# Fnlwgt                0.032197    0.000152      0.009289 -0.023882  0.025387
# Education            -0.040654   -0.038231     -0.012720  0.011158 -0.027880
# Education_num        -0.063457    0.087778     -0.091928  0.032791  0.006131
# Marital_status        1.000000    0.022702      0.177975 -0.068641 -0.119837
# Occupation            0.022702    1.000000     -0.053742  0.000736  0.062350
# Relationship          0.177975   -0.053742      1.000000 -0.117140 -0.584876
# Race                 -0.068641    0.000736     -0.117140  1.000000  0.089178
# Sex                  -0.119837    0.062350     -0.584876  0.089178  1.000000
# Capital_gain         -0.042424    0.022170     -0.058258  0.014351  0.048811
# Capital_loss         -0.035197    0.014597     -0.063569  0.023520  0.047017
# Hours_per_week       -0.189004    0.018362     -0.257851  0.048533  0.231272
# Native_country       -0.025911   -0.003470     -0.010806  0.124511  0.000612
# Income               -0.193504    0.051551     -0.251009  0.071666  0.216715
#
#                 Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# Age                 0.080154      0.060166        0.101599       -0.001905
# Workclass           0.035340      0.007226        0.050738        0.007644
# Fnlwgt              0.000427     -0.009757       -0.022889       -0.066709
# Education           0.030577      0.015025        0.059887        0.078794
# Education_num       0.124413      0.079656        0.152528        0.091547
# Marital_status     -0.042424     -0.035197       -0.189004       -0.025911
# Occupation          0.022170      0.014597        0.018362       -0.003470
# Relationship       -0.058258     -0.063569       -0.257851       -0.010806
# Race                0.014351      0.023520        0.048533        0.124511
# Sex                 0.048811      0.047017        0.231272        0.000612
# Capital_gain        1.000000     -0.032228        0.080432        0.008529
# Capital_loss       -0.032228      1.000000        0.052417        0.009388
# Hours_per_week      0.080432      0.052417        1.000000        0.008408
# Native_country      0.008529      0.009388        0.008408        1.000000
# Income              0.221200      0.150050        0.229480        0.023273
#
#                   Income
# Age             0.242000
# Workclass       0.018103
# Fnlwgt         -0.008978
# Education       0.078981
# Education_num   0.335317
# Marital_status -0.193504
# Occupation      0.051551
# Relationship   -0.251009
# Race            0.071666
# Sex             0.216715
# Capital_gain    0.221200
# Capital_loss    0.150050
# Hours_per_week  0.229480
# Native_country  0.023273
# Income          1.000000

# %%
df.corr()['Income'].sort_values()
# Out:
# Relationship     -0.251009
# Marital_status   -0.193504
# Fnlwgt           -0.008978
# Workclass         0.018103
# Native_country    0.023273
# Occupation        0.051551
# Race              0.071666
# Education         0.078981
# Capital_loss      0.150050
# Sex               0.216715
# Capital_gain      0.221200
# Hours_per_week    0.229480
# Age               0.242000
# Education_num     0.335317
# Income            1.000000
# Name: Income, dtype: float64

# %%
# Correlation using Heatmap
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,linewidth=0.5,linecolor='Black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
#Desribing Datasets (For Numerical Values)
df.describe()
# Out:
#                 Age     Workclass        Fnlwgt     Education  Education_num  \
# count  30161.000000  30161.000000  3.016100e+04  30161.000000   30161.000000
# mean      38.437883      2.199231  1.897976e+05     10.333809      10.121216
# std       13.134882      0.953804  1.056527e+05      3.812347       2.549983
# min       17.000000      0.000000  1.376900e+04      0.000000       1.000000
# 25%       28.000000      2.000000  1.176280e+05      9.000000       9.000000
# 50%       37.000000      2.000000  1.784290e+05     11.000000      10.000000
# 75%       47.000000      2.000000  2.376300e+05     12.000000      13.000000
# max       90.000000      6.000000  1.484705e+06     15.000000      16.000000
#
#        Marital_status    Occupation  Relationship          Race           Sex  \
# count    30161.000000  30161.000000  30161.000000  30161.000000  30161.000000
# mean         2.580087      5.960048      1.418355      3.678592      0.675674
# std          1.498018      4.029487      1.601363      0.834721      0.468130
# min          0.000000      0.000000      0.000000      0.000000      0.000000
# 25%          2.000000      2.000000      0.000000      4.000000      0.000000
# 50%          2.000000      6.000000      1.000000      4.000000      1.000000
# 75%          4.000000      9.000000      3.000000      4.000000      1.000000
# max          6.000000     13.000000      5.000000      4.000000      1.000000
#
#        Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# count  30161.000000  30161.000000    30161.000000    30161.000000
# mean    1091.971984     88.375419       40.931269       36.382514
# std     7406.466659    404.304753       11.980182        6.105467
# min        0.000000      0.000000        1.000000        0.000000
# 25%        0.000000      0.000000       40.000000       38.000000
# 50%        0.000000      0.000000       40.000000       38.000000
# 75%        0.000000      0.000000       45.000000       38.000000
# max    99999.000000   4356.000000       99.000000       40.000000
#
#              Income
# count  30161.000000
# mean       0.248931
# std        0.432401
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
plt.figure(figsize=(15,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variables Summary")
plt.savefig('heatamap.png')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30161 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             30161 non-null  int64
#  1   Workclass       30161 non-null  int32
#  2   Fnlwgt          30161 non-null  int64
#  3   Education       30161 non-null  int32
#  4   Education_num   30161 non-null  int64
#  5   Marital_status  30161 non-null  int32
#  6   Occupation      30161 non-null  int32
#  7   Relationship    30161 non-null  int32
#  8   Race            30161 non-null  int32
#  9   Sex             30161 non-null  int32
#  10  Capital_gain    30161 non-null  int64
#  11  Capital_loss    30161 non-null  int64
#  12  Hours_per_week  30161 non-null  int64
#  13  Native_country  30161 non-null  int32
#  14  Income          30161 non-null  int64
# dtypes: int32(8), int64(7)
# memory usage: 3.8 MB

# %%
#Outliers Checking

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
collist = df.columns.values
ncol = 30
nrows = 14
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(data=df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %%
#Skewness
df.skew()
# Out:
# Age                0.530223
# Workclass          1.154786
# Fnlwgt             1.459212
# Education         -0.944971
# Education_num     -0.305328
# Marital_status    -0.009387
# Occupation         0.110420
# Relationship       0.820275
# Race              -2.506976
# Sex               -0.750584
# Capital_gain      11.902511
# Capital_loss       4.526294
# Hours_per_week     0.330856
# Native_country    -4.178826
# Income             1.161357
# dtype: float64

# %%
# Skewness between -065 to 0.65
#Clumns are ("Pregnancies,BloodPressure,Insulin,DiabetesPedigreeFunction,Age")

# %%
# Normal Distribution Curve

# %%
sns.distplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Workclass'])
# Out:
# <AxesSubplot:xlabel='Workclass', ylabel='Density'>

# %%
sns.distplot(df['Fnlwgt'])
# Out:
# <AxesSubplot:xlabel='Fnlwgt', ylabel='Density'>

# %%
sns.distplot(df['Education'])
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Density'>

# %%
sns.distplot(df['Education_num'])
# Out:
# <AxesSubplot:xlabel='Education_num', ylabel='Density'>

# %%
sns.distplot(df['Marital_status'])
# Out:
# <AxesSubplot:xlabel='Marital_status', ylabel='Density'>

# %%
sns.distplot(df['Occupation'])
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='Density'>

# %%
sns.distplot(df['Relationship'])
# Out:
# <AxesSubplot:xlabel='Relationship', ylabel='Density'>

# %%
sns.distplot(df['Race'])
# Out:
# <AxesSubplot:xlabel='Race', ylabel='Density'>

# %%
sns.distplot(df['Sex'])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Density'>

# %%
sns.distplot(df['Capital_gain'])
# Out:
# <AxesSubplot:xlabel='Capital_gain', ylabel='Density'>

# %%
sns.distplot(df['Capital_loss'])
# Out:
# <AxesSubplot:xlabel='Capital_loss', ylabel='Density'>

# %%
sns.distplot(df['Native_country'])
# Out:
# <AxesSubplot:xlabel='Native_country', ylabel='Density'>

# %%
df.corr()['Income']
# Out:
# Age               0.234039
# Workclass         0.051645
# Fnlwgt           -0.009481
# Education         0.079311
# Education_num     0.335182
# Marital_status   -0.199295
# Occupation        0.075448
# Relationship     -0.250924
# Race              0.071853
# Sex               0.215995
# Capital_gain      0.223333
# Capital_loss      0.150523
# Hours_per_week    0.229690
# Native_country    0.015845
# Income            1.000000
# Name: Income, dtype: float64

# %%
# Removing Outliers

# %%
from scipy.stats import zscore

# %%
import numpy as np
z=np.abs(zscore(df))

# %%
z.shape
# Out:
# (32560, 15)

# %%
z
# Out:
#             Age  Workclass    Fnlwgt  Education  Education_num  \
# 0      0.837097   1.463883  1.008742   0.335443       1.134779
# 1      0.042640   0.090121  0.245046   0.181319       0.420027
# 2      1.057031   0.090121  0.425770   2.402489       1.197429
# 3      0.775755   0.090121  1.408146   0.335443       1.134779
# 4      0.115952   0.090121  0.898170   0.439700       1.523480
# ...         ...        ...       ...        ...            ...
# 32555  0.849066   0.090121  0.639710   0.852204       0.746077
# 32556  0.103982   0.090121  0.335466   0.181319       0.420027
# 32557  1.423589   0.090121  0.358811   0.181319       0.420027
# 32558  1.215624   0.090121  0.110927   0.181319       0.420027
# 32559  0.983720   0.777002  0.929862   0.181319       0.420027
#
#        Marital_status  Occupation  Relationship      Race       Sex  \
# 0            0.406183    0.608434      0.900177  0.393675  0.703087
# 1            1.734026    0.135480      0.277810  0.393675  0.703087
# 2            0.406183    0.135480      0.900177  1.962583  0.703087
# 3            0.406183    0.810427      2.211658  1.962583  1.422298
# 4            0.406183    0.608434      2.211658  0.393675  1.422298
# ...               ...         ...           ...       ...       ...
# 32555        0.406183    1.519858      2.211658  0.393675  1.422298
# 32556        0.406183    0.100997      0.900177  0.393675  0.703087
# 32557        2.249503    1.317864      1.589291  0.393675  1.422298
# 32558        0.921660    1.317864      0.966924  0.393675  0.703087
# 32559        0.406183    0.608434      2.211658  0.393675  1.422298
#
#        Capital_gain  Capital_loss  Hours_per_week  Native_country    Income
# 0          0.145914      0.216663        2.222120        0.291573  0.563210
# 1          0.145914      0.216663        0.035430        0.291573  0.563210
# 2          0.145914      0.216663        0.035430        0.291573  0.563210
# 3          0.145914      0.216663        0.035430        4.054157  0.563210
# 4          0.145914      0.216663        0.035430        0.291573  0.563210
# ...             ...           ...             ...             ...       ...
# 32555      0.145914      0.216663        0.197407        0.291573  0.563210
# 32556      0.145914      0.216663        0.035430        0.291573  1.775537
# 32557      0.145914      0.216663        0.035430        0.291573  0.563210
# 32558      0.145914      0.216663        1.655200        0.291573  0.563210
# 32559      1.888401      0.216663        0.035430        0.291573  1.775537
#
# [32560 rows x 15 columns]

# %%
# threshold = (-3,3)
#if applied np.abs
threshold = 3

#index number
print(np.where(z>3))
# Out:
# (array([    3,     9,    10, ..., 32532, 32550, 32552], dtype=int64), array([13, 12,  8, ...,  8,  8,  8], dtype=int64))

# %%
len(np.where(z>3)[0])
# Out:
# 5667

# %%
df_new=df[(z<3).all(axis=1)]

# %%
print("Old Dataframe",df.shape)
print("New Dataframe",df_new.shape)
print("Total Dropped Rows",df.shape[0] - df_new.shape[0])
# Out:
# Old Dataframe (32560, 15)
# New Dataframe (27417, 15)
# Total Dropped Rows 5143

# %%
# Percentage Data Loss

# %%
loss_percent = (32560-27414)/32560*100
print(loss_percent,'%')
# Out:
# 15.804668304668304 %

# %%
# Model without outliers df

df_new
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          6   83311          9             13               2
# 1       38          4  215646         11              9               0
# 2       53          4  234721          1              7               2
# 4       37          4  284582         12             14               2
# 5       49          4  160187          6              5               3
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          4  257302          7             12               2
# 32556   40          4  154374         11              9               2
# 32557   58          4  151910         11              9               6
# 32558   22          4  201490         11              9               4
# 32559   52          5  287927         11              9               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0               4             0     4    1             0             0
# 1               6             1     4    1             0             0
# 2               6             0     2    1             0             0
# 4               4             5     4    0             0             0
# 5               8             1     2    0             0             0
# ...           ...           ...   ...  ...           ...           ...
# 32555          13             5     4    0             0             0
# 32556           7             0     4    1             0             0
# 32557           1             4     4    0             0             0
# 32558           1             3     4    1             0             0
# 32559           4             5     4    0         15024             0
#
#        Hours_per_week  Native_country  Income
# 0                  13              39       0
# 1                  40              39       0
# 2                  40              39       0
# 4                  40              39       0
# 5                  16              23       0
# ...               ...             ...     ...
# 32555              38              39       0
# 32556              40              39       1
# 32557              40              39       0
# 32558              20              39       0
# 32559              40              39       1
#
# [27417 rows x 15 columns]

# %%
#independant Column
x=df_new.iloc[:,:-1]

# %%
#target
y=df_new.iloc[:,-1]

# %%
# Transforming data to remove skewness
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')
x
# Out:
# array([[ 0.92387928,  1.65209239, -1.12465326, ..., -0.04054646,
#         -2.21338681,  0.17213488],
#        [ 0.12850238,  0.01669779,  0.41302315, ..., -0.04054646,
#         -0.03813668,  0.17213488],
#        [ 1.09846907,  0.01669779,  0.59312735, ..., -0.04054646,
#         -0.03813668,  0.17213488],
#        ...,
#        [ 1.37259752,  0.01669779, -0.24852704, ..., -0.04054646,
#         -0.03813668,  0.17213488],
#        [-1.32725084,  0.01669779,  0.27467596, ..., -0.04054646,
#         -1.71987004,  0.17213488],
#        [ 1.04117247,  0.80120487,  1.06334322, ..., -0.04054646,
#         -0.03813668,  0.17213488]])

# %%
#Using methos Standard Scalar
from sklearn.preprocessing import StandardScaler
#Transform standard normal distribution
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 0.92387928,  1.65209239, -1.12465326, ..., -0.04054646,
#         -2.21338681,  0.17213488],
#        [ 0.12850238,  0.01669779,  0.41302315, ..., -0.04054646,
#         -0.03813668,  0.17213488],
#        [ 1.09846907,  0.01669779,  0.59312735, ..., -0.04054646,
#         -0.03813668,  0.17213488],
#        ...,
#        [ 1.37259752,  0.01669779, -0.24852704, ..., -0.04054646,
#         -0.03813668,  0.17213488],
#        [-1.32725084,  0.01669779,  0.27467596, ..., -0.04054646,
#         -1.71987004,  0.17213488],
#        [ 1.04117247,  0.80120487,  1.06334322, ..., -0.04054646,
#         -0.03813668,  0.17213488]])

# %%
x.mean()
# Out:
# 3.5171900592025553e-19

# %%
# Only two classes so use binary classification

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score

# %%
#Splitting the DataFrame

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train = lr.predict(x_train)
    pred_test = lr.predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100,1) == round(accuracy_score(y_test,pred_test)*100,1):
        print("At Random State",i,"The model performs very well")
        print("At Random State:-",i)
        print("Training accuracy score is:-",round(accuracy_score(y_train,pred_train)*100,1))
        print("Testing accuracy score is:-",round(accuracy_score(y_test,pred_test)*100,1),'\n\n')
# Out:
# At Random State 3 The model performs very well
# At Random State:- 3
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 43 The model performs very well
# At Random State:- 43
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 57 The model performs very well
# At Random State:- 57
# Training accuracy score is:- 82.8
# Testing accuracy score is:- 82.8
#
#
# At Random State 129 The model performs very well
# At Random State:- 129
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 142 The model performs very well
# At Random State:- 142
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 157 The model performs very well
# At Random State:- 157
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 177 The model performs very well
# At Random State:- 177
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 214 The model performs very well
# At Random State:- 214
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 230 The model performs very well
# At Random State:- 230
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 236 The model performs very well
# At Random State:- 236
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 240 The model performs very well
# At Random State:- 240
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 252 The model performs very well
# At Random State:- 252
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 256 The model performs very well
# At Random State:- 256
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 271 The model performs very well
# At Random State:- 271
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 286 The model performs very well
# At Random State:- 286
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 292 The model performs very well
# At Random State:- 292
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 300 The model performs very well
# At Random State:- 300
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 334 The model performs very well
# At Random State:- 334
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 385 The model performs very well
# At Random State:- 385
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 399 The model performs very well
# At Random State:- 399
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 400 The model performs very well
# At Random State:- 400
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 426 The model performs very well
# At Random State:- 426
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 445 The model performs very well
# At Random State:- 445
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 494 The model performs very well
# At Random State:- 494
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 524 The model performs very well
# At Random State:- 524
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 526 The model performs very well
# At Random State:- 526
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 551 The model performs very well
# At Random State:- 551
# Training accuracy score is:- 82.8
# Testing accuracy score is:- 82.8
#
#
# At Random State 566 The model performs very well
# At Random State:- 566
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 597 The model performs very well
# At Random State:- 597
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 628 The model performs very well
# At Random State:- 628
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 629 The model performs very well
# At Random State:- 629
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 630 The model performs very well
# At Random State:- 630
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 636 The model performs very well
# At Random State:- 636
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 638 The model performs very well
# At Random State:- 638
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 654 The model performs very well
# At Random State:- 654
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 664 The model performs very well
# At Random State:- 664
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 723 The model performs very well
# At Random State:- 723
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 757 The model performs very well
# At Random State:- 757
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 759 The model performs very well
# At Random State:- 759
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 777 The model performs very well
# At Random State:- 777
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 778 The model performs very well
# At Random State:- 778
# Training accuracy score is:- 82.8
# Testing accuracy score is:- 82.8
#
#
# At Random State 779 The model performs very well
# At Random State:- 779
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 806 The model performs very well
# At Random State:- 806
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 823 The model performs very well
# At Random State:- 823
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 850 The model performs very well
# At Random State:- 850
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 870 The model performs very well
# At Random State:- 870
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 887 The model performs very well
# At Random State:- 887
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 911 The model performs very well
# At Random State:- 911
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 920 The model performs very well
# At Random State:- 920
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 942 The model performs very well
# At Random State:- 942
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 961 The model performs very well
# At Random State:- 961
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 974 The model performs very well
# At Random State:- 974
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 976 The model performs very well
# At Random State:- 976
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9
#
#
# At Random State 981 The model performs very well
# At Random State:- 981
# Training accuracy score is:- 82.9
# Testing accuracy score is:- 82.9

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=177)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.85      0.81      4241
#            1       0.23      0.15      0.18      1243
#
#     accuracy                           0.69      5484
#    macro avg       0.50      0.50      0.49      5484
# weighted avg       0.65      0.69      0.67      5484

# %%
#Cross Validation score for logistic regression

# %%
pred_lr=lr.predict(x_test)
from sklearn.model_selection import cross_val_score
lss=accuracy_score(y_test,pred_lr)

# %%
for j in range(2,10):
    lsscore = cross_val_score(lr,x,y,cv=j)
    lsc=lsscore.mean()
    print("At CV:-",j)
    print("Cross Validation Score is:-",lsc*100)
    print("accuracy Score is:-",lss*100)
    print("\n")
# Out:
# At CV:- 2
# Cross Validation Score is:- 82.87559277212793
# accuracy Score is:- 82.6221735959154
#
#
# At CV:- 3
# Cross Validation Score is:- 82.81723018565123
# accuracy Score is:- 82.6221735959154
#
#
# At CV:- 4
# Cross Validation Score is:- 82.85371541095651
# accuracy Score is:- 82.6221735959154
#
#
# At CV:- 5
# Cross Validation Score is:- 82.8573617838467
# accuracy Score is:- 82.6221735959154
#
#
# At CV:- 6
# Cross Validation Score is:- 82.84641095231731
# accuracy Score is:- 82.6221735959154
#
#
# At CV:- 7
# Cross Validation Score is:- 82.86830061735185
# accuracy Score is:- 82.6221735959154
#
#
# At CV:- 8
# Cross Validation Score is:- 82.87197572029926
# accuracy Score is:- 82.6221735959154
#
#
# At CV:- 9
# Cross Validation Score is:- 82.84279370286704
# accuracy Score is:- 82.6221735959154

# %%
lsscore_selected = cross_val_score(lr,x,y,cv=7).mean()
print("The CV Score is:",lsscore_selected,"\n The accuracy score is:",lss)
# Out:
# The CV Score is: 0.8286830061735185
#  The accuracy score is: 0.8262217359591539

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier

# %%
knn=KNeighborsClassifier()
dt=DecisionTreeClassifier()
rf=RandomForestClassifier()
adb=AdaBoostClassifier()
svm=SVC()      
gdboost=GradientBoostingClassifier()

# %%
knn.fit(x_train,y_train)
dt.fit(x_train,y_train)
rf.fit(x_train,y_train)
adb.fit(x_train,y_train)
svm.fit(x_train,y_train)
gdboost.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
print("knn classification score",knn.score(x_train,y_train))
print("dt classification score",dt.score(x_train,y_train))
print("rf classification score",rf.score(x_train,y_train))
print("adb classification score",adb.score(x_train,y_train))
print("svm classification score",svm.score(x_train,y_train))
print("gdboost classification score",gdboost.score(x_train,y_train))
# Out:
# knn classification score 0.876669858204532
# dt classification score 0.999954406601924
# rf classification score 0.9999088132038481
# adb classification score 0.8592075867414398
# svm classification score 0.8435234578033101
# gdboost classification score 0.8671408380066566

# %%
#Model Evalution

# %%
knn_yprad = knn.predict(x_test)
dt_yprad = dt.predict(x_test)
rf_yprad = rf.predict(x_test)
adb_yprad = adb.predict(x_test)
svm_yprad = svm.predict(x_test)
gdboost_yprad = gdboost.predict(x_test)

# %%
from sklearn import metrics
knn_conf_mat = metrics.confusion_matrix(y_test,knn_yprad)
print("confusion matrix for knn_model",'\n',knn_conf_mat)
# Out:
# confusion matrix for knn_model
#  [[3832  409]
#  [ 536  707]]

# %%
dt_conf_mat = metrics.confusion_matrix(y_test,dt_yprad)
print("confusion matrix for kdt_model",'\n',dt_conf_mat)
# Out:
# confusion matrix for kdt_model
#  [[3725  516]
#  [ 510  733]]

# %%
rf_conf_mat = metrics.confusion_matrix(y_test,rf_yprad)
print("confusion matrix for rf_model",'\n',rf_conf_mat)
# Out:
# confusion matrix for rf_model
#  [[3960  281]
#  [ 514  729]]

# %%
adb_conf_mat = metrics.confusion_matrix(y_test,adb_yprad)
print("confusion matrix for adb_model",'\n',adb_conf_mat)
# Out:
# confusion matrix for adb_model
#  [[4039  202]
#  [ 569  674]]

# %%
svm_conf_mat = metrics.confusion_matrix(y_test,svm_yprad)
print("confusion matrix for svm_model",'\n',svm_conf_mat)
# Out:
# confusion matrix for svm_model
#  [[4037  204]
#  [ 686  557]]

# %%
gdboost_conf_mat = metrics.confusion_matrix(y_test,gdboost_yprad)
print("confusion matrix for gdboost_model",'\n',gdboost_conf_mat)
# Out:
# confusion matrix for gdboost_model
#  [[4055  186]
#  [ 543  700]]

# %%
#Checking Classification report for all model

# %%
knn_report = classification_report(y_test,knn_yprad)
print(" knn classification_report" ,'\n',knn_report)
# Out:
#  knn classification_report
#                precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89      4241
#            1       0.63      0.57      0.60      1243
#
#     accuracy                           0.83      5484
#    macro avg       0.76      0.74      0.74      5484
# weighted avg       0.82      0.83      0.82      5484

# %%
dt_report = classification_report(y_test,dt_yprad)
print(" dt classification_report" ,'\n',dt_report)
# Out:
#  dt classification_report
#                precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88      4241
#            1       0.59      0.59      0.59      1243
#
#     accuracy                           0.81      5484
#    macro avg       0.73      0.73      0.73      5484
# weighted avg       0.81      0.81      0.81      5484

# %%
rf_report = classification_report(y_test,rf_yprad)
print(" rf classification_report" ,'\n',rf_report)
# Out:
#  rf classification_report
#                precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      4241
#            1       0.72      0.59      0.65      1243
#
#     accuracy                           0.86      5484
#    macro avg       0.80      0.76      0.78      5484
# weighted avg       0.85      0.86      0.85      5484

# %%
adb_report = classification_report(y_test,adb_yprad)
print(" adb classification_report" ,'\n',adb_report)
# Out:
#  adb classification_report
#                precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91      4241
#            1       0.77      0.54      0.64      1243
#
#     accuracy                           0.86      5484
#    macro avg       0.82      0.75      0.77      5484
# weighted avg       0.85      0.86      0.85      5484

# %%
svm_report = classification_report(y_test,svm_yprad)
print(" svm classification_report" ,'\n',svm_report)
# Out:
#  svm classification_report
#                precision    recall  f1-score   support
#
#            0       0.85      0.95      0.90      4241
#            1       0.73      0.45      0.56      1243
#
#     accuracy                           0.84      5484
#    macro avg       0.79      0.70      0.73      5484
# weighted avg       0.83      0.84      0.82      5484

# %%
gdboost_report = classification_report(y_test,gdboost_yprad)
print(" gdboost classification_report" ,'\n',gdboost_report)
# Out:
#  gdboost classification_report
#                precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92      4241
#            1       0.79      0.56      0.66      1243
#
#     accuracy                           0.87      5484
#    macro avg       0.84      0.76      0.79      5484
# weighted avg       0.86      0.87      0.86      5484

# %%
#Cross Validation score for all model

# %%
pred_knn=knn.predict(x_test)
from sklearn.model_selection import cross_val_score
kss=accuracy_score(y_test,pred_knn)

# %%
for j in range(2,10):
    kscore = cross_val_score(knn,x,y,cv=j)
    ksc=kscore.mean()
    print("At CV:-",j)
    print("Cross Validation Score is:-",ksc*100)
    print("accuracy Score is:-",kss*100)
    print("\n")
# Out:
# At CV:- 2
# Cross Validation Score is:- 82.41967192813448
# accuracy Score is:- 82.76805251641139
#
#
# At CV:- 3
# Cross Validation Score is:- 82.780756464967
# accuracy Score is:- 82.76805251641139
#
#
# At CV:- 4
# Cross Validation Score is:- 82.45249889484055
# accuracy Score is:- 82.76805251641139
#
#
# At CV:- 5
# Cross Validation Score is:- 82.36497985351713
# accuracy Score is:- 82.76805251641139
#
#
# At CV:- 6
# Cross Validation Score is:- 82.62761172835869
# accuracy Score is:- 82.76805251641139
#
#
# At CV:- 7
# Cross Validation Score is:- 82.54369700543539
# accuracy Score is:- 82.76805251641139
#
#
# At CV:- 8
# Cross Validation Score is:- 82.51452766809253
# accuracy Score is:- 82.76805251641139
#
#
# At CV:- 9
# Cross Validation Score is:- 82.55099235778164
# accuracy Score is:- 82.76805251641139

# %%
kscore_selected = cross_val_score(knn,x,y,cv=7).mean()
print("The CV Score is:",kscore_selected,"\n The accuracy score is:",kss)
# Out:
# The CV Score is: 0.8286830061735185
#  The accuracy score is: 0.8276805251641138

# %%
pred_dt=dt.predict(x_test)
from sklearn.model_selection import cross_val_score
dss=accuracy_score(y_test,pred_dt)

# %%
for j in range(2,10):
    dscore = cross_val_score(dt,x,y,cv=j)
    dsc=dscore.mean()
    print("At CV:-",j)
    print("Cross Validation Score is:-",dsc*100)
    print("accuracy Score is:-",dss*100)
    print("\n")
# Out:
# At CV:- 2
# Cross Validation Score is:- 80.69447065790338
# accuracy Score is:- 81.2910284463895
#
#
# At CV:- 3
# Cross Validation Score is:- 80.33701717912245
# accuracy Score is:- 81.2910284463895
#
#
# At CV:- 4
# Cross Validation Score is:- 80.63610467099876
# accuracy Score is:- 81.2910284463895
#
#
# At CV:- 5
# Cross Validation Score is:- 80.63245748778833
# accuracy Score is:- 81.2910284463895
#
#
# At CV:- 6
# Cross Validation Score is:- 80.41728906264093
# accuracy Score is:- 81.2910284463895
#
#
# At CV:- 7
# Cross Validation Score is:- 80.60329038254416
# accuracy Score is:- 81.2910284463895
#
#
# At CV:- 8
# Cross Validation Score is:- 80.82214062838895
# accuracy Score is:- 81.2910284463895
#
#
# At CV:- 9
# Cross Validation Score is:- 80.77106796182059
# accuracy Score is:- 81.2910284463895

# %%
dscore_selected = cross_val_score(dt,x,y,cv=7).mean()
print("The CV Score is:",dscore_selected,"\n The accuracy score is:",dss)
# Out:
# The CV Score is: 0.8062518885135942
#  The accuracy score is: 0.812910284463895

# %%
pred_rf=rf.predict(x_test)
from sklearn.model_selection import cross_val_score
rss=accuracy_score(y_test,pred_rf)

# %%
for j in range(2,10):
    rscore = cross_val_score(rf,x,y,cv=j)
    rsc=rscore.mean()
    print("At CV:-",j)
    print("Cross Validation Score is:-",rsc*100)
    print("accuracy Score is:-",rss*100)
    print("\n")
# Out:
# At CV:- 2
# Cross Validation Score is:- 85.1880306575824
# accuracy Score is:- 85.50328227571116
#
#
# At CV:- 3
# Cross Validation Score is:- 85.22084837874311
# accuracy Score is:- 85.50328227571116
#
#
# At CV:- 4
# Cross Validation Score is:- 85.36674267098897
# accuracy Score is:- 85.50328227571116
#
#
# At CV:- 5
# Cross Validation Score is:- 85.18074499351022
# accuracy Score is:- 85.50328227571116
#
#
# At CV:- 6
# Cross Validation Score is:- 85.29746736122786
# accuracy Score is:- 85.50328227571116
#
#
# At CV:- 7
# Cross Validation Score is:- 85.24276035484739
# accuracy Score is:- 85.50328227571116
#
#
# At CV:- 8
# Cross Validation Score is:- 85.33396186471698
# accuracy Score is:- 85.50328227571116
#
#
# At CV:- 9
# Cross Validation Score is:- 85.32665294376814
# accuracy Score is:- 85.50328227571116

# %%
rscore_selected = cross_val_score(rf,x,y,cv=7).mean()
print("The CV Score is:",rscore_selected,"\n The accuracy score is:",rss)
# Out:
# The CV Score is: 0.8533394731872701
#  The accuracy score is: 0.8550328227571116

# %%
pred_adb=adb.predict(x_test)
from sklearn.model_selection import cross_val_score
ass=accuracy_score(y_test,pred_adb)

# %%
for j in range(2,10):
    ascore = cross_val_score(adb,x,y,cv=j)
    asc=ascore.mean()
    print("At CV:-",j)
    print("Cross Validation Score is:-",asc*100)
    print("accuracy Score is:-",ass*100)
    print("\n")
# Out:
# At CV:- 2
# Cross Validation Score is:- 85.96127486744942
# accuracy Score is:- 85.94091903719912
#
#
# At CV:- 3
# Cross Validation Score is:- 86.00868074552285
# accuracy Score is:- 85.94091903719912
#
#
# At CV:- 4
# Cross Validation Score is:- 85.91021561091746
# accuracy Score is:- 85.94091903719912
#
#
# At CV:- 5
# Cross Validation Score is:- 85.87011069158395
# accuracy Score is:- 85.94091903719912
#
#
# At CV:- 6
# Cross Validation Score is:- 85.91388562026238
# accuracy Score is:- 85.94091903719912
#
#
# At CV:- 7
# Cross Validation Score is:- 85.9321118222823
# accuracy Score is:- 85.94091903719912
#
#
# At CV:- 8
# Cross Validation Score is:- 85.91389070389272
# accuracy Score is:- 85.94091903719912
#
#
# At CV:- 9
# Cross Validation Score is:- 85.93574932870595
# accuracy Score is:- 85.94091903719912

# %%
ascore_selected = cross_val_score(adb,x,y,cv=7).mean()
print("The CV Score is:",ascore_selected,"\n The accuracy score is:",ass)
# Out:
# The CV Score is: 0.859321118222823
#  The accuracy score is: 0.8594091903719913

# %%
svm_yprad = svm.predict(x_test)
gdboost_yprad = gdboost.predict(x_test)

# %%
pred_svm=svm.predict(x_test)
from sklearn.model_selection import cross_val_score
sss=accuracy_score(y_test,pred_svm)

# %%
for j in range(2,10):
    sscore = cross_val_score(svm,x,y,cv=j)
    ssc=sscore.mean()
    print("At CV:-",j)
    print("Cross Validation Score is:-",ssc*100)
    print("accuracy Score is:-",sss*100)
    print("\n")
# Out:
# At CV:- 2
# Cross Validation Score is:- 83.68895315257147
# accuracy Score is:- 83.7709700948213
#
#
# At CV:- 3
# Cross Validation Score is:- 83.79107852792063
# accuracy Score is:- 83.7709700948213
#
#
# At CV:- 4
# Cross Validation Score is:- 83.94062936516703
# accuracy Score is:- 83.7709700948213
#
#
# At CV:- 5
# Cross Validation Score is:- 83.81297447065681
# accuracy Score is:- 83.7709700948213
#
#
# At CV:- 6
# Cross Validation Score is:- 83.88228059613999
# accuracy Score is:- 83.7709700948213
#
#
# At CV:- 7
# Cross Validation Score is:- 83.80931637027939
# accuracy Score is:- 83.7709700948213
#
#
# At CV:- 8
# Cross Validation Score is:- 83.93699826588158
# accuracy Score is:- 83.7709700948213
#
#
# At CV:- 9
# Cross Validation Score is:- 83.92605126144525
# accuracy Score is:- 83.7709700948213

# %%
sscore_selected = cross_val_score(svm,x,y,cv=7).mean()
print("The CV Score is:",sscore_selected,"\n The accuracy score is:",sss)
# Out:
# The CV Score is: 0.8380931637027939
#  The accuracy score is: 0.837709700948213

# %%
pred_gdboost=gdboost.predict(x_test)
from sklearn.model_selection import cross_val_score
gss=accuracy_score(y_test,pred_gdboost)

# %%
for j in range(2,10):
    gscore = cross_val_score(gdboost,x,y,cv=j)
    gsc=gscore.mean()
    print("At CV:-",j)
    print("Cross Validation Score is:-",gsc*100)
    print("accuracy Score is:-",gss*100)
    print("\n")
# Out:
# At CV:- 2
# Cross Validation Score is:- 86.34789018768818
# accuracy Score is:- 86.70678336980306
#
#
# At CV:- 3
# Cross Validation Score is:- 86.3260021154758
# accuracy Score is:- 86.70678336980306
#
#
# At CV:- 4
# Cross Validation Score is:- 86.33695402089683
# accuracy Score is:- 86.70678336980306
#
#
# At CV:- 5
# Cross Validation Score is:- 86.39167771799926
# accuracy Score is:- 86.70678336980306
#
#
# At CV:- 6
# Cross Validation Score is:- 86.32238491122187
# accuracy Score is:- 86.70678336980306
#
#
# At CV:- 7
# Cross Validation Score is:- 86.36978317153756
# accuracy Score is:- 86.70678336980306
#
#
# At CV:- 8
# Cross Validation Score is:- 86.3807585891297
# accuracy Score is:- 86.70678336980306
#
#
# At CV:- 9
# Cross Validation Score is:- 86.41356186506245
# accuracy Score is:- 86.70678336980306

# %%
gscore_selected = cross_val_score(gdboost,x,y,cv=7).mean()
print("The CV Score is:",gscore_selected,"\n The accuracy score is:",gss)
# Out:
# The CV Score is: 0.8636978317153756
#  The accuracy score is: 0.8670678336980306

# %%
#As compare above model XGBoost is highest accuracy

# %%
#Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

parameters={'n_estimators' : [5,50],
            'max_depth' : [1,3],  
              'learning_rate': [0.01,0.1]}

# %%
GCV=GridSearchCV(gdboost,parameters,cv=5)
GCV.fit(x_train,y_train)
GCV.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}

# %%
type(GCV)
# Out:
# sklearn.model_selection._search.GridSearchCV

# %%
GCV.best_estimator_
# Out:
# GradientBoostingClassifier(n_estimators=50)

# %%
GCV_pred=GCV.best_estimator_.predict(x_test)
accuracy_score(y_test,GCV_pred)
# Out:
# 0.8584974471188913

# %%
#ROC AUC plot
import matplotlib.pyplot as plt
from sklearn.metrics import plot_roc_curve
plot_roc_curve(GCV.best_estimator_,x_test,y_test)
plt.title("ROC AUC plot")
plt.show()

# %%
import pickle
filename ='EV_Census_Income'
pickle.dump(rf,open(filename,'wb'))
