# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('D:/I/02.Flip Robo Assignments/00.DataTrained Assignment/bigdatamart_rep/bigdatamart_Train.csv')
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
pd.read_csv('D:/I/02.Flip Robo Assignments/00.DataTrained Assignment/bigdatamart_rep/bigdatamart_Test.csv')
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
df=pd.read_csv('D:/I/02.Flip Robo Assignments/00.DataTrained Assignment/bigdatamart_rep/bigdatamart_Train.csv')

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.tail(2)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8521           FDN46         7.21          Regular         0.145221
# 8522           DRG01        14.80          Low Fat         0.044878
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 8521  Snack Foods  103.1332            OUT018                       2009
# 8522  Soft Drinks   75.4670            OUT046                       1997
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 8521      Medium               Tier 3  Supermarket Type2          1845.5976
# 8522       Small               Tier 1  Supermarket Type1           765.6700

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
df["Item_Weight"]=df["Item_Weight"].fillna(np.mean(df["Item_Weight"]))

# %%
df['Outlet_Size'] = df['Outlet_Size'].fillna(df['Outlet_Size'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
#Encoding of data

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               156.0        9.300               1.0         0.016047
# 1                 8.0        5.920               2.0         0.019278
# 2               662.0       17.500               1.0         0.016760
# 3              1121.0       19.200               2.0         0.000000
# 4              1297.0        8.930               1.0         0.000000
# ...               ...          ...               ...              ...
# 8518            370.0        6.865               1.0         0.056783
# 8519            897.0        8.380               2.0         0.046982
# 8520           1357.0       10.600               1.0         0.035186
# 8521            681.0        7.210               2.0         0.145221
# 8522             50.0       14.800               1.0         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df.describe()
# Out:
#        Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# count      8523.000000  8523.000000       8523.000000      8523.000000
# mean        779.714889    12.857645          1.369354         0.066132
# std         449.222377     4.226124          0.644810         0.051598
# min           0.000000     4.555000          0.000000         0.000000
# 25%         395.500000     9.310000          1.000000         0.026989
# 50%         783.000000    12.857645          1.000000         0.053931
# 75%        1167.000000    16.000000          2.000000         0.094585
# max        1558.000000    21.350000          4.000000         0.328391
#
#          Item_Type     Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# count  8523.000000  8523.000000        8523.000000                8523.000000
# mean      7.226681   140.992782           4.722281                1997.831867
# std       4.209990    62.275067           2.837201                   8.371760
# ...

# %%
#EDA Part Using Scaterplot
import seaborn as sns

# %%
sns.scatterplot(x="Item_Identifier",y="Item_Outlet_Sales",data=df)
# Out:
# <AxesSubplot:xlabel='Item_Identifier', ylabel='Item_Outlet_Sales'>

# %%
sns.scatterplot(x="Item_Weight",y="Item_Outlet_Sales",data=df)
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Item_Outlet_Sales'>

# %%
sns.scatterplot(x="Item_Fat_Content",y="Item_Outlet_Sales",data=df)
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='Item_Outlet_Sales'>

# %%
sns.scatterplot(x="Item_Visibility",y="Item_Outlet_Sales",data=df)
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Item_Outlet_Sales'>

# %%
sns.scatterplot(x="Item_Type",y="Item_Outlet_Sales",data=df)
# Out:
# <AxesSubplot:xlabel='Item_Type', ylabel='Item_Outlet_Sales'>

# %%
sns.scatterplot(x="Item_MRP",y="Item_Outlet_Sales",data=df)
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Item_Outlet_Sales'>

# %%
sns.scatterplot(x="Outlet_Identifier",y="Item_Outlet_Sales",data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Identifier', ylabel='Item_Outlet_Sales'>

# %%
sns.scatterplot(x="Outlet_Establishment_Year",y="Item_Outlet_Sales",data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='Item_Outlet_Sales'>

# %%
sns.scatterplot(x="Outlet_Size",y="Item_Outlet_Sales",data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='Item_Outlet_Sales'>

# %%
sns.scatterplot(x="Outlet_Location_Type",y="Item_Outlet_Sales",data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type', ylabel='Item_Outlet_Sales'>

# %%
sns.scatterplot(x="Outlet_Type",y="Item_Outlet_Sales",data=df)
# Out:
# <AxesSubplot:xlabel='Outlet_Type', ylabel='Item_Outlet_Sales'>

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.describe()
# Out:
#        Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# count      8523.000000  8523.000000       8523.000000      8523.000000
# mean        779.714889    12.857645          1.369354         0.066132
# std         449.222377     4.226124          0.644810         0.051598
# min           0.000000     4.555000          0.000000         0.000000
# 25%         395.500000     9.310000          1.000000         0.026989
# 50%         783.000000    12.857645          1.000000         0.053931
# 75%        1167.000000    16.000000          2.000000         0.094585
# max        1558.000000    21.350000          4.000000         0.328391
#
#          Item_Type     Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# count  8523.000000  8523.000000        8523.000000                8523.000000
# mean      7.226681   140.992782           4.722281                1997.831867
# std       4.209990    62.275067           2.837201                   8.371760
# ...

# %%
#Correlation

# %%
df.corr()
# Out:
#                            Item_Identifier  Item_Weight  Item_Fat_Content  \
# Item_Identifier                   1.000000     0.044518         -0.098114
# Item_Weight                       0.044518     1.000000         -0.017331
# Item_Fat_Content                 -0.098114    -0.017331          1.000000
# Item_Visibility                  -0.025482    -0.012049          0.034042
# Item_Type                        -0.017973     0.028015         -0.115958
# Item_MRP                          0.012853     0.024756         -0.000876
# Outlet_Identifier                -0.008602    -0.007975         -0.002357
# Outlet_Establishment_Year        -0.012772    -0.008301         -0.000189
# Outlet_Size                       0.001389    -0.007225         -0.012058
# Outlet_Location_Type              0.003656     0.004088         -0.004102
# Outlet_Type                      -0.001178    -0.000566         -0.004214
# Item_Outlet_Sales                 0.002869     0.011550          0.009800
#
# ...

# %%
df.corr()['Item_Outlet_Sales'].sort_values()
# Out:
# Item_Visibility             -0.128625
# Outlet_Size                 -0.086182
# Outlet_Establishment_Year   -0.049135
# Item_Identifier              0.002869
# Item_Fat_Content             0.009800
# Item_Weight                  0.011550
# Item_Type                    0.017048
# Outlet_Location_Type         0.089367
# Outlet_Identifier            0.162325
# Outlet_Type                  0.401522
# Item_MRP                     0.567574
# Item_Outlet_Sales            1.000000
# Name: Item_Outlet_Sales, dtype: float64

# %%
# Correlation using Heatmap
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,linewidth=0.5,linecolor='Black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='density',subplots=True,layout=(6,11),sharex=False,legend=False,fontsize=1,figsize=(18,12))
plt.show()

# %%
x=df.drop("Item_Outlet_Sales",axis=1)
y=df["Item_Outlet_Sales"]

# %%
x
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               156.0        9.300               1.0         0.016047
# 1                 8.0        5.920               2.0         0.019278
# 2               662.0       17.500               1.0         0.016760
# 3              1121.0       19.200               2.0         0.000000
# 4              1297.0        8.930               1.0         0.000000
# ...               ...          ...               ...              ...
# 8518            370.0        6.865               1.0         0.056783
# 8519            897.0        8.380               2.0         0.046982
# 8520           1357.0       10.600               1.0         0.035186
# 8521            681.0        7.210               2.0         0.145221
# 8522             50.0       14.800               1.0         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
y
# Out:
# 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 3        732.3800
# 4        994.7052
#           ...
# 8518    2778.3834
# 8519     549.2850
# 8520    1193.1136
# 8521    1845.5976
# 8522     765.6700
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %%
#Skewness
x.skew().sort_values(ascending=False)
# Out:
# Item_Visibility              1.167091
# Item_Fat_Content             0.994824
# Outlet_Type                  0.927438
# Item_MRP                     0.127202
# Item_Type                    0.101655
# Item_Weight                  0.090561
# Item_Identifier             -0.008877
# Outlet_Identifier           -0.059861
# Outlet_Size                 -0.087072
# Outlet_Location_Type        -0.209093
# Outlet_Establishment_Year   -0.396641
# dtype: float64

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#Using Power Transformation 
from sklearn.preprocessing import power_transform
x_new = power_transform(df)
x_new
# Out:
# array([[-1.46103862, -0.82263635, -0.52097741, ..., -1.37384276,
#         -0.12348771,  0.98507755],
#        [-2.09385818, -1.73380133,  1.00987141, ...,  1.08832445,
#          1.04059102, -1.21813513],
#        [-0.15401841,  1.08636176, -0.52097741, ..., -1.37384276,
#         -0.12348771,  0.22036037],
#        ...,
#        [ 1.20607271, -0.49655592, -0.52097741, ..., -0.13111325,
#         -0.12348771, -0.39304411],
#        [-0.11255898, -1.37344321,  1.00987141, ...,  1.08832445,
#          1.04059102,  0.0706692 ],
#        [-1.86245653,  0.49178563, -0.52097741, ..., -1.37384276,
#         -0.12348771, -0.79793408]])

# %%
# Checking skewness
pd.DataFrame(x_new,columns=df.columns).skew().sort_values(ascending=False)
# Out:
# Item_Visibility              0.124279
# Item_Fat_Content             0.032643
# Outlet_Type                  0.007863
# Outlet_Size                 -0.042980
# Item_Weight                 -0.068024
# Item_Outlet_Sales           -0.074791
# Item_MRP                    -0.115386
# Item_Type                   -0.164574
# Outlet_Establishment_Year   -0.200959
# Outlet_Identifier           -0.213935
# Outlet_Location_Type        -0.220632
# Item_Identifier             -0.293700
# dtype: float64

# %%
# To checking Outliers

# %%
collist = x.columns.values
ncol = 30
nrows = 14
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(data=x[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %%
df["Item_Visibility"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["Item_Fat_Content"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["Outlet_Type"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["Outlet_Size"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["Item_Weight"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["Item_Outlet_Sales"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["Item_MRP"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["Item_Type"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["Outlet_Establishment_Year"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["Outlet_Identifier"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["Outlet_Location_Type"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df["Item_Identifier"].plot.box()
# Out:
# <AxesSubplot:>

# %%
# Removing Outliers Using Z score
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
threshold = 3
np.where(z>3)
# Out:
# (array([  49,   81,   83,  108,  130,  145,  151,  174,  199,  276,  304,
#          333,  339,  373,  396,  434,  456,  472,  489,  502,  521,  532,
#          615,  661,  694,  727,  753,  753,  809,  838,  854,  891,  935,
#          991,  997, 1009, 1010, 1034, 1090, 1124, 1133, 1138, 1159, 1183,
#         1209, 1254, 1272, 1291, 1311, 1324, 1372, 1433, 1434, 1450, 1496,
#         1501, 1506, 1512, 1542, 1549, 1560, 1575, 1576, 1615, 1617, 1644,
#         1651, 1684, 1723, 1753, 1769, 1805, 1827, 1841, 1859, 1998, 2062,
#         2088, 2109, 2111, 2122, 2143, 2168, 2173, 2216, 2223, 2238, 2251,
#         2293, 2324, 2331, 2438, 2439, 2445, 2516, 2535, 2552, 2569, 2586,
#         2613, 2660, 2678, 2728, 2776, 2855, 2895, 2905, 2971, 2973, 3011,
#         3017, 3083, 3087, 3098, 3154, 3206, 3225, 3234, 3241, 3242, 3243,
#         3286, 3335, 3367, 3399, 3407, 3458, 3474, 3480, 3488, 3491, 3497,
#         3509, 3540, 3545, 3582, 3602, 3667, 3709, 3720, 3750, 3757, 3767,
# ...

# %%
df_new_z=df[(z<3).all(axis=1)]
df_new_z
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               156.0        9.300               1.0         0.016047
# 1                 8.0        5.920               2.0         0.019278
# 2               662.0       17.500               1.0         0.016760
# 3              1121.0       19.200               2.0         0.000000
# 4              1297.0        8.930               1.0         0.000000
# ...               ...          ...               ...              ...
# 8518            370.0        6.865               1.0         0.056783
# 8519            897.0        8.380               2.0         0.046982
# 8520           1357.0       10.600               1.0         0.035186
# 8521            681.0        7.210               2.0         0.145221
# 8522             50.0       14.800               1.0         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df.shape
# Out:
# (8523, 12)

# %%
df_new_z.shape
# Out:
# (8222, 12)

# %%
data_loss=((8523-8222)/8523)*100

# %%
data_loss
# Out:
# 3.5316203214830457

# %%
features=df.drop("Item_Outlet_Sales",axis=1)
target=df["Item_Outlet_Sales"]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split

# %%
#Best Random State
maxAccu=0
maxRS=0

for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=i)
    LR=LogisticRegression()
    LR.fit(x_train,y_train)
    predrf=LR.predict(x_test)
    acc=accuracy_score(y_test,predrf)
    print('accuracy',acc,'random_state',i)
    
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
        print('max_accuracy',maxAccu,'max_random_state',i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15860/1981070157.py in <module>
#       6     x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=i)
#       7     LR=LogisticRegression()
# ----> 8     LR.fit(x_train,y_train)
#       9     predrf=LR.predict(x_test)
#      10     acc=accuracy_score(y_test,predrf)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
# -> 1347         check_classification_targets(y)
#    1348         self.classes_ = np.unique(y)
#    1349
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
# ...

# %%
#Using methos Min Max Scalar
from sklearn.preprocessing import MinMaxScaler
#Transform standard normal distribution
mns=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train = lr.predict(x_train)
    pred_test = lr.predict(x_test)
    print(f"At Random State{i},The training accuracy is:- {r2_score(y_train,pred_train)}")
    print(f"At Random State{i},The testing accuracy is:- {r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# At Random State0,The training accuracy is:- 0.5095637584210898
# At Random State0,The testing accuracy is:- 0.5127044026662453
#
#
# At Random State1,The training accuracy is:- 0.5102315378105475
# At Random State1,The testing accuracy is:- 0.5093274544624926
#
#
# At Random State2,The training accuracy is:- 0.5140207882509149
# At Random State2,The testing accuracy is:- 0.49469407947463184
#
#
# At Random State3,The training accuracy is:- 0.5014271456689643
# At Random State3,The testing accuracy is:- 0.5440519386858895
#
#
# At Random State4,The training accuracy is:- 0.5126567470805997
# At Random State4,The testing accuracy is:- 0.49819408358524975
#
#
# At Random State5,The training accuracy is:- 0.5121406622636986
# At Random State5,The testing accuracy is:- 0.5021400687818707
#
#
# At Random State6,The training accuracy is:- 0.5103657349919776
# At Random State6,The testing accuracy is:- 0.5085999530194933
#
#
# At Random State7,The training accuracy is:- 0.5140939682558932
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-1.38851383, -0.84187169, -0.57284357, ..., -0.28458121,
#         -1.36933384, -0.25265831],
#        [-1.71799137, -1.64170589,  0.97809218, ..., -0.28458121,
#          1.09156913,  1.00297245],
#        [-0.26205684,  1.09855449, -0.57284357, ..., -0.28458121,
#         -1.36933384, -0.25265831],
#        ...,
#        [ 1.28515188, -0.53424315, -0.57284357, ...,  1.38127431,
#         -0.13888236, -0.25265831],
#        [-0.21975905, -1.33644372,  0.97809218, ..., -0.28458121,
#          1.09156913,  1.00297245],
#        [-1.62449099,  0.45963367, -0.57284357, ...,  1.38127431,
#         -1.36933384, -0.25265831]])

# %%
x.mean()
# Out:
# 1.0762388530672408e-15

# %%
#Continue with MinMaxScalar

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=166)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.5149037595252552

# %%
# Cross Validation Model

# %%
Train_accuracy=r2_score(y_train,pred_train)
Test_accuracy=r2_score(y_test,pred_test)

# %%
for j in range(2,10):
    lsscore = cross_val_score(lr,x,y,cv=j)
    lsc=lsscore.mean()
    print("At CV:-",j)
    print("Cross Validation Score is:-",lsc*100)
    print("accuracy Score for training is:-",Train_accuracy*100)
    print("accuracy Score for test is:-",Test_accuracy*100)
    print("\n")
# Out:
# At CV:- 2
# Cross Validation Score is:- 50.79599317555341
# accuracy Score for training is:- -48.64021045648379
# accuracy Score for test is:- 51.490375952525525
#
#
# At CV:- 3
# Cross Validation Score is:- 50.83027462662118
# accuracy Score for training is:- -48.64021045648379
# accuracy Score for test is:- 51.490375952525525
#
#
# At CV:- 4
# Cross Validation Score is:- 50.65814414173039
# accuracy Score for training is:- -48.64021045648379
# accuracy Score for test is:- 51.490375952525525
#
#
# At CV:- 5
# Cross Validation Score is:- 50.785406536301345
# accuracy Score for training is:- -48.64021045648379
# accuracy Score for test is:- 51.490375952525525
#
#
# At CV:- 6
# Cross Validation Score is:- 50.765794985998895
# accuracy Score for training is:- -48.64021045648379
# accuracy Score for test is:- 51.490375952525525
#
#
# At CV:- 7
# Cross Validation Score is:- 50.83878501302266
# accuracy Score for training is:- -48.64021045648379
# ...

# %%
lsscore_selected = cross_val_score(lr,x,y,cv=5).mean()
print("The CV Score is:",lsscore_selected,"\n The accuracy score is:",Test_accuracy)
# Out:
# The CV Score is: 0.5078540653630135
#  The accuracy score is: 0.5149037595252552

# %%
# AUC ROC Curve:

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=target_test,y=pred_test,color='r')
plt.plot(target_test,pred_test,color='b')
plt.xlabel('Actual Value',fontsize=14)
plt.ylabel('Predicted Value',fontsize=14)
plt.title('Linear Regression',fontsize=18)
plt.show()

# %%
#Model Saving

import pickle
filename = 'Big_Train1'
pickle.dump(lr,open(filename,'wb'))

# %%
# Conclusion:

import numpy as np
a=np.array(y_test)
predicted = np.array(lr.predict(x_test))
df_com=pd.DataFrame({"origional":a,"predicted":predicted},index=range(len(a)))
df_com
# Out:
#       origional    predicted
# 0     2291.0178  2269.388092
# 1     3010.7476  2471.042495
# 2     3435.5280  4000.689941
# 3     3994.8000  2280.041072
# 4     2182.4924  3690.872865
# ...         ...          ...
# 1700   459.4020  1360.007192
# 1701  1661.8368   788.680712
# 1702   820.2656  2020.584704
# 1703   710.4086  1374.651716
# 1704  3874.2902  3958.418548
#
# [1705 rows x 2 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split

# %%
#Best Random State
maxAccu=0
maxRS=0

for i in range(1,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=i)
    LR=LogisticRegression()
    LR.fit(x_train,y_train)
    predrf=LR.predict(x_test)
    acc=accuracy_score(y_test,predrf)
    print('accuracy',acc,'random_state',i)
    
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
        print('max_accuracy',maxAccu,'max_random_state',i)
# Out:
# accuracy 0.7247141600703606 random_state 1
# max_accuracy 0.7247141600703606 max_random_state 1
# accuracy 0.723834652594547 random_state 2
# accuracy 0.7229551451187335 random_state 3
# accuracy 0.6992084432717678 random_state 4
# accuracy 0.7255936675461742 random_state 5
# max_accuracy 0.7255936675461742 max_random_state 5
# accuracy 0.7150395778364116 random_state 6
# accuracy 0.7264731750219877 random_state 7
# max_accuracy 0.7264731750219877 max_random_state 7
# accuracy 0.7150395778364116 random_state 8
# accuracy 0.6666666666666666 random_state 9
# accuracy 0.6965699208443272 random_state 10
# accuracy 0.6965699208443272 random_state 11
# accuracy 0.7220756376429199 random_state 12
# accuracy 0.7203166226912929 random_state 13
# accuracy 0.7229551451187335 random_state 14
# accuracy 0.7053649956024626 random_state 15
# accuracy 0.7185576077396658 random_state 16
# accuracy 0.7247141600703606 random_state 17
# accuracy 0.7282321899736148 random_state 18
# ...

# %%
pd.read_csv('D:/I/02.Flip Robo Assignments/00.DataTrained Assignment/bigdatamart_rep/bigdatamart_Test.csv')
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
df1=pd.read_csv('D:/I/02.Flip Robo Assignments/00.DataTrained Assignment/bigdatamart_rep/bigdatamart_Test.csv')

# %%
df1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
df1.head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
df1.tail(2)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 5679           FDJ26         15.3          Regular          0.00000    Canned
# 5680           FDU37          9.5          Regular          0.10472    Canned
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 5679  214.6218            OUT017                       2007         NaN
# 5680   79.7960            OUT045                       2002         NaN
#
#      Outlet_Location_Type        Outlet_Type
# 5679               Tier 2  Supermarket Type1
# 5680               Tier 2  Supermarket Type1

# %%
df1.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
df1.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# dtype: object

# %%
df1["Item_Weight"]=df["Item_Weight"].fillna(np.mean(df["Item_Weight"]))

# %%
df1['Outlet_Size'] = df['Outlet_Size'].fillna(df['Outlet_Size'].mode()[0])

# %%
df1.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
#Making DataFrame for Nominal Data

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in df1.columns:
    if df1[i].dtypes=='object':
        df1[i]=enc.fit_transform(df1[i].values.reshape(-1,1))

# %%
df1
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0              1103.0     9.300000               1.0         0.007565
# 1              1067.0     5.920000               4.0         0.038428
# 2              1406.0    17.500000               1.0         0.099575
# 3               809.0    19.200000               1.0         0.015388
# 4              1184.0     8.930000               2.0         0.118599
# ...               ...          ...               ...              ...
# 5676            231.0    15.100000               2.0         0.013496
# 5677            306.0    12.150000               2.0         0.142991
# 5678           1412.0    10.695000               1.0         0.073529
# 5679            517.0    12.857645               2.0         0.000000
# 5680            987.0     7.825000               2.0         0.104720
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
sns.scatterplot(x='Item_Identifier',y='Outlet_Type',data=df1)
# Out:
# <AxesSubplot:xlabel='Item_Identifier', ylabel='Outlet_Type'>

# %%
sns.scatterplot(x='Item_Weight',y='Outlet_Type',data=df1)
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Outlet_Type'>

# %%
sns.scatterplot(x='Item_Fat_Content',y='Outlet_Type',data=df1)
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='Outlet_Type'>

# %%
sns.scatterplot(x='Item_Visibility',y='Outlet_Type',data=df1)
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Outlet_Type'>

# %%
sns.scatterplot(x='Item_Type',y='Outlet_Type',data=df1)
# Out:
# <AxesSubplot:xlabel='Item_Type', ylabel='Outlet_Type'>

# %%
sns.scatterplot(x='Item_MRP',y='Outlet_Type',data=df1)
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Outlet_Type'>

# %%
sns.scatterplot(x='Outlet_Identifier',y='Outlet_Type',data=df1)
# Out:
# <AxesSubplot:xlabel='Outlet_Identifier', ylabel='Outlet_Type'>

# %%
sns.scatterplot(x='Outlet_Establishment_Year',y='Outlet_Type',data=df1)
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='Outlet_Type'>

# %%
sns.scatterplot(x='Outlet_Size',y='Outlet_Type',data=df1)
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='Outlet_Type'>

# %%
sns.scatterplot(x='Outlet_Location_Type',y='Outlet_Type',data=df1)
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type', ylabel='Outlet_Type'>

# %%
df1.shape
# Out:
# (5681, 11)

# %%
#Correlation

# %%
df1.corr()
# Out:
#                            Item_Identifier  Item_Weight  Item_Fat_Content  \
# Item_Identifier                   1.000000    -0.000166         -0.093344
# Item_Weight                      -0.000166     1.000000          0.004581
# Item_Fat_Content                 -0.093344     0.004581          1.000000
# Item_Visibility                  -0.063856    -0.001710          0.033591
# Item_Type                        -0.003236     0.007119         -0.128945
# Item_MRP                          0.007537    -0.023962         -0.014283
# Outlet_Identifier                 0.010162     0.018968         -0.000792
# Outlet_Establishment_Year         0.011728     0.001970         -0.010088
# Outlet_Size                      -0.019713    -0.004851          0.015102
# Outlet_Location_Type             -0.011657    -0.019452         -0.000130
# Outlet_Type                      -0.009553    -0.014198          0.000387
#
#                            Item_Visibility  Item_Type  Item_MRP  \
# ...

# %%
df1.corr()['Outlet_Type'].sort_values()
# Out:
# Item_Visibility             -0.154042
# Outlet_Establishment_Year   -0.122841
# Item_Weight                 -0.014198
# Item_Identifier             -0.009553
# Item_Fat_Content             0.000387
# Outlet_Size                  0.001574
# Item_MRP                     0.003326
# Item_Type                    0.006179
# Outlet_Identifier            0.099937
# Outlet_Location_Type         0.467299
# Outlet_Type                  1.000000
# Name: Outlet_Type, dtype: float64

# %%
# Correlation using Heatmap
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
sns.heatmap(df1.corr(),annot=True,linewidth=0.5,linecolor='Black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind='density',subplots=True,layout=(6,11),sharex=False,legend=False,fontsize=1,figsize=(18,12))
plt.show()

# %%
x1=df1.drop("Outlet_Type",axis=1)
y1=df1["Outlet_Type"]

# %%
x1
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0              1103.0     9.300000               1.0         0.007565
# 1              1067.0     5.920000               4.0         0.038428
# 2              1406.0    17.500000               1.0         0.099575
# 3               809.0    19.200000               1.0         0.015388
# 4              1184.0     8.930000               2.0         0.118599
# ...               ...          ...               ...              ...
# 5676            231.0    15.100000               2.0         0.013496
# 5677            306.0    12.150000               2.0         0.142991
# 5678           1412.0    10.695000               1.0         0.073529
# 5679            517.0    12.857645               2.0         0.000000
# 5680            987.0     7.825000               2.0         0.104720
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
y1
# Out:
# 0       1.0
# 1       1.0
# 2       0.0
# 3       1.0
# 4       3.0
#        ...
# 5676    1.0
# 5677    2.0
# 5678    1.0
# 5679    1.0
# 5680    1.0
# Name: Outlet_Type, Length: 5681, dtype: float64

# %%
# There is no multicolinearity Checking Skewness
df1.skew()
# Out:
# Item_Identifier             -0.000020
# Item_Weight                  0.068050
# Item_Fat_Content             0.999629
# Item_Visibility              1.238312
# Item_Type                    0.096486
# Item_MRP                     0.136182
# Outlet_Identifier           -0.060209
# Outlet_Establishment_Year   -0.396306
# Outlet_Size                 -0.088234
# Outlet_Location_Type        -0.209049
# Outlet_Type                  0.927446
# dtype: float64

# %%
df1.skew().sort_values(ascending=False)
# Out:
# Item_Visibility              1.238312
# Item_Fat_Content             0.999629
# Outlet_Type                  0.927446
# Item_MRP                     0.136182
# Item_Type                    0.096486
# Item_Weight                  0.068050
# Item_Identifier             -0.000020
# Outlet_Identifier           -0.060209
# Outlet_Size                 -0.088234
# Outlet_Location_Type        -0.209049
# Outlet_Establishment_Year   -0.396306
# dtype: float64

# %%
#Removing skewness using power transform method

# %%
from sklearn.preprocessing import power_transform
df1_new=power_transform(df1)

# %%
df1_new
# Out:
# array([[ 0.75746742, -0.83660197, -0.5240889 , ..., -0.28881967,
#         -1.37374464, -0.12353311],
#        [ 0.68861828, -1.73217566,  3.19413231, ..., -0.28881967,
#         -0.13101959, -0.12353311],
#        [ 1.31359527,  1.06453518, -0.5240889 , ..., -0.28881967,
#          1.08829997, -1.91575348],
#        ...,
#        [ 1.32423381, -0.49081631, -0.5240889 , ..., -0.28881967,
#         -0.13101959, -0.12353311],
#        [-0.47261831,  0.02450491,  1.01563473, ..., -0.28881967,
#         -0.13101959, -0.12353311],
#        [ 0.53315531, -1.21602813,  1.01563473, ..., -1.91804558,
#         -0.13101959, -0.12353311]])

# %%
#Checking Skewness

# %%
pd.DataFrame(df1_new,columns=df1.columns).skew().sort_values(ascending=False)
# Out:
# Item_Visibility              0.116776
# Item_Fat_Content             0.032646
# Outlet_Type                  0.007830
# Outlet_Size                 -0.044010
# Item_Weight                 -0.073149
# Item_MRP                    -0.111040
# Item_Type                   -0.167431
# Outlet_Establishment_Year   -0.200515
# Outlet_Identifier           -0.214064
# Outlet_Location_Type        -0.220642
# Item_Identifier             -0.285982
# dtype: float64

# %%
# To checking Outliers

# %%
df1.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
collist = x1.columns.values
ncol = 30
nrows = 14
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(data=x1[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %%
df1.dtypes
# Out:
# Item_Identifier              float64
# Item_Weight                  float64
# Item_Fat_Content             float64
# Item_Visibility              float64
# Item_Type                    float64
# Item_MRP                     float64
# Outlet_Identifier            float64
# Outlet_Establishment_Year      int64
# Outlet_Size                  float64
# Outlet_Location_Type         float64
# Outlet_Type                  float64
# dtype: object

# %%
df1["Item_Identifier"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df1["Item_Weight"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df1["Item_Fat_Content"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df1["Item_Visibility"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df1["Item_Type"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df1["Item_MRP"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df1["Outlet_Identifier"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df1["Outlet_Establishment_Year"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df1["Outlet_Size"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df1["Outlet_Location_Type"].plot.box()
# Out:
# <AxesSubplot:>

# %%
df1["Outlet_Type"].plot.box()
# Out:
# <AxesSubplot:>

# %%
# Removing Outliers Using Z score
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df1))
threshold = 3
np.where(z>3)
# Out:
# (array([   1,   46,   76,   78,   89,  103,  138,  242,  333,  369,  385,
#          474,  499,  543,  595,  637,  739,  783,  797,  815,  858,  871,
#          985,  996, 1025, 1037, 1046, 1105, 1143, 1191, 1256, 1256, 1270,
#         1284, 1314, 1321, 1411, 1422, 1437, 1516, 1539, 1547, 1577, 1616,
#         1710, 1757, 1780, 1812, 1823, 1853, 1857, 1915, 1919, 1927, 2019,
#         2070, 2167, 2179, 2230, 2271, 2275, 2365, 2365, 2380, 2393, 2504,
#         2516, 2561, 2595, 2605, 2609, 2625, 2628, 2677, 2779, 2798, 2836,
#         2843, 2866, 2915, 2926, 3039, 3077, 3097, 3267, 3294, 3313, 3316,
#         3346, 3357, 3362, 3378, 3461, 3502, 3565, 3622, 3638, 3679, 3744,
#         3778, 3783, 3950, 3970, 4021, 4052, 4133, 4146, 4147, 4148, 4159,
#         4208, 4232, 4255, 4328, 4330, 4334, 4340, 4352, 4365, 4421, 4478,
#         4542, 4575, 4616, 4616, 4689, 4692, 4726, 4801, 4804, 4845, 4846,
#         4870, 4919, 4921, 4941, 4965, 4970, 4976, 4999, 5121, 5132, 5154,
# ...

# %%
df1_new_z=df1[(z<3).all(axis=1)]
df1_new_z
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0              1103.0     9.300000               1.0         0.007565
# 2              1406.0    17.500000               1.0         0.099575
# 3               809.0    19.200000               1.0         0.015388
# 4              1184.0     8.930000               2.0         0.118599
# 5               461.0    10.395000               2.0         0.063817
# ...               ...          ...               ...              ...
# 5676            231.0    15.100000               2.0         0.013496
# 5677            306.0    12.150000               2.0         0.142991
# 5678           1412.0    10.695000               1.0         0.073529
# 5679            517.0    12.857645               2.0         0.000000
# 5680            987.0     7.825000               2.0         0.104720
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df1.shape
# Out:
# (5681, 11)

# %%
df1_new_z.shape
# Out:
# (5525, 11)

# %%
data_loss=((5681-5525)/5681)*100

# %%
data_loss
# Out:
# 2.745995423340961

# %%
#Findin best random state
import warnings
warnings.filterwarnings('ignore')

# %%
#Using methos Standard Scalar
from sklearn.preprocessing import StandardScaler
#Transform standard normal distribution
sc=StandardScaler()
x1=sc.fit_transform(x1)
x1
# Out:
# array([[ 0.73989552, -0.853795  , -0.57528374, ...,  0.13989058,
#         -0.2800338 , -1.369215  ],
#        [ 0.65908503, -1.64850884,  4.10469757, ...,  1.09551169,
#         -0.2800338 , -0.1388274 ],
#        [ 1.42005049,  1.07420898, -0.57528374, ...,  0.02043794,
#         -0.2800338 ,  1.0915602 ],
#        ...,
#        [ 1.43351891, -0.5257992 , -0.57528374, ...,  0.4982485 ,
#         -0.2800338 , -0.1388274 ],
#        [-0.57551969, -0.0173128 ,  0.98471003, ...,  1.09551169,
#         -0.2800338 , -0.1388274 ],
#        [ 0.47950616, -1.2006006 ,  0.98471003, ...,  0.4982485 ,
#         -1.94238698, -0.1388274 ]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x1,y1,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train = lr.predict(x_train)
    pred_test = lr.predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100,1) == round(accuracy_score(y_test,pred_test)*100,1):
        print("At Random State",i,"The model performs very well")
        print("At Random State:-",i)
        print("Training accuracy score is:-",round(accuracy_score(y_train,pred_train)*100,1))
        print("Testing accuracy score is:-",round(accuracy_score(y_test,pred_test)*100,1),'\n\n')
# Out:
# At Random State 0 The model performs very well
# At Random State:- 0
# Training accuracy score is:- 100.0
# Testing accuracy score is:- 100.0
#
#
# At Random State 1 The model performs very well
# At Random State:- 1
# Training accuracy score is:- 100.0
# Testing accuracy score is:- 100.0
#
#
# At Random State 2 The model performs very well
# At Random State:- 2
# Training accuracy score is:- 100.0
# Testing accuracy score is:- 100.0
#
#
# At Random State 3 The model performs very well
# At Random State:- 3
# Training accuracy score is:- 100.0
# Testing accuracy score is:- 100.0
#
#
# At Random State 4 The model performs very well
# At Random State:- 4
# Training accuracy score is:- 100.0
# Testing accuracy score is:- 100.0
#
#
# At Random State 5 The model performs very well
# At Random State:- 5
# Training accuracy score is:- 100.0
# Testing accuracy score is:- 100.0
#
#
# At Random State 6 The model performs very well
# At Random State:- 6
# Training accuracy score is:- 100.0
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x1,y1,test_size=0.20,random_state=54)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.12      0.12      0.12       149
#          1.0       0.64      0.64      0.64       716
#          2.0       0.16      0.13      0.15       141
#          3.0       0.13      0.15      0.14       131
#
#     accuracy                           0.45      1137
#    macro avg       0.26      0.26      0.26      1137
# weighted avg       0.45      0.45      0.45      1137

# %%
#Cross Validation score for logistic regression

# %%
pred_lr=lr.predict(x_test)
from sklearn.model_selection import cross_val_score
lss=accuracy_score(y_test,pred_lr)

# %%
for j in range(2,10):
    lsscore = cross_val_score(lr,x1,y1,cv=j)
    lsc=lsscore.mean()
    print("At CV:-",j)
    print("Cross Validation Score is:-",lsc*100)
    print("accuracy Score is:-",lss*100)
    print("\n")
# Out:
# At CV:- 2
# Cross Validation Score is:- 99.98239436619718
# accuracy Score is:- 100.0
#
#
# At CV:- 3
# Cross Validation Score is:- 100.0
# accuracy Score is:- 100.0
#
#
# At CV:- 4
# Cross Validation Score is:- 100.0
# accuracy Score is:- 100.0
#
#
# At CV:- 5
# Cross Validation Score is:- 100.0
# accuracy Score is:- 100.0
#
#
# At CV:- 6
# Cross Validation Score is:- 100.0
# accuracy Score is:- 100.0
#
#
# At CV:- 7
# Cross Validation Score is:- 100.0
# accuracy Score is:- 100.0
#
#
# At CV:- 8
# Cross Validation Score is:- 100.0
# accuracy Score is:- 100.0
#
#
# At CV:- 9
# Cross Validation Score is:- 100.0
# accuracy Score is:- 100.0

# %%
lsscore_selected = cross_val_score(lr,x1,y1,cv=7).mean()
print("The CV Score is:",lsscore_selected,"\n The accuracy score is:",lss)
# Out:
# The CV Score is: 1.0
#  The accuracy score is: 1.0
